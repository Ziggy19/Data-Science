# %% [markdown]
# # Pandas - Plotting

# %%
import pandas as pd

df = pd.read_csv('Z:\Study\ziggy std\Mr. Prakash Senapathi\dataset/new missing data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0       NaN
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1       NaN
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2       NaN
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.fillna(78345.67 ,inplace=True)
df
# Out:
#     YearsExperience     Salary
# 0               1.1   39343.00
# 1               1.3   46205.00
# 2               1.5   37731.00
# 3               2.0   43525.00
# 4               2.2   39891.00
# 5               2.9   56642.00
# 6               3.0   78345.67
# 7               3.2   54445.00
# 8               3.2   64445.00
# 9               3.7   57189.00
# 10              3.9   63218.00
# 11              4.0   55794.00
# 12              4.0   56957.00
# 13              4.1   78345.67
# 14              4.5   61111.00
# 15              4.9   67938.00
# 16              5.1   66029.00
# 17              5.3   83088.00
# 18              5.9   81363.00
# 19              6.0   93940.00
# 20              6.8   91738.00
# 21              7.1   98273.00
# 22              7.9  101302.00
# 23              8.2   78345.67
# 24              8.7  109431.00
# 25              9.0  105582.00
# 26              9.5  116969.00
# 27              9.6  112635.00
# 28             10.3  122391.00
# 29             10.5  121872.00

# %%
df.corr()
# Out:
#                  YearsExperience   Salary
# YearsExperience          1.00000  0.94783
# Salary                   0.94783  1.00000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#Scatter plot
df.plot(kind='scatter', x='YearsExperience',y='Salary')
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
df['Salary'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
